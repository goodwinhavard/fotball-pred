# %%
import numpy as np

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import requests
import json
import sys
import os
import streamlit as st
import numpy as np

# %%
uri = 'https://api.football-data.org/v4/competitions/PL/standings'
headers = {'X-Auth-Token': 'b006736168e34387975ae15e83b341a4'}

# %%
response = requests.get(uri, headers=headers, timeout=10)
response.raise_for_status()

# %%
print(response)
# Out:
# <Response [200]>

# %%
import pandas as pd

uri = 'https://api.football-data.org/v4/competitions/PL/standings'
headers = {'X-Auth-Token': 'b006736168e34387975ae15e83b341a4'}

response = requests.get(uri, headers=headers, timeout=20)
response.raise_for_status()
data = response.json()
standings = data['standings'][0]['table']

df = pd.DataFrame([
    {
        'Pos': team['position'],
        'Team': team['team']['shortName'],
        'P': team['playedGames'],
        'W': team['won'],
        'D': team['draw'],
        'L': team['lost'],
        'GF': team['goalsFor'],
        'GA': team['goalsAgainst'],
        'GD': team['goalDifference'],
        'Pts': team['points'],
    }
    for team in standings
])

print(df.to_string(index=False))
df
# Out:
#  Pos           Team  P  W  D  L  GF  GA  GD  Pts
#    1       Man City  3  3  0  0   7   2   5    9
#    2      Hull City  3  2  1  0   3   0   3    7
#    3        Arsenal  2  2  0  0   4   0   4    6
#    4        Chelsea  2  2  0  0   7   5   2    6
#    5      Brentford  3  1  2  0   5   2   3    5
#    6      Liverpool  3  1  2  0   6   4   2    5
#    6      Newcastle  3  1  2  0   6   4   2    5
#    8   Leeds United  3  1  2  0   3   2   1    5
#    9  Brighton Hove  3  1  1  1   8   5   3    4
#   10        Everton  2  1  1  0   3   1   2    4
#   11     Sunderland  3  1  1  1   3   3   0    4
#   12     Man United  2  1  0  1   5   4   1    3
#   13 Crystal Palace  3  1  0  2   4   8  -4    3
#   13   Ipswich Town  3  1  0  2   4   8  -4    3
#   15    Bournemouth  3  0  2  1   4   5  -1    2
#   16     Nottingham  3  0  2  1   2   3  -1    2
#   17    Aston Villa  3  0  1  2   0   5  -5    1
#   17      Tottenham  3  0  1  2   0   5  -5    1
#   19         Fulham  3  0  0  3   4   7  -3    0
#   20  Coventry City  3  0  0  3   0   5  -5    0
#     Pos            Team  P  W  D  L  GF  GA  GD  Pts
# 0     1        Man City  3  3  0  0   7   2   5    9
# 1     2       Hull City  3  2  1  0   3   0   3    7
# 2     3         Arsenal  2  2  0  0   4   0   4    6
# 3     4         Chelsea  2  2  0  0   7   5   2    6
# 4     5       Brentford  3  1  2  0   5   2   3    5
# 5     6       Liverpool  3  1  2  0   6   4   2    5
# 6     6       Newcastle  3  1  2  0   6   4   2    5
# 7     8    Leeds United  3  1  2  0   3   2   1    5
# 8     9   Brighton Hove  3  1  1  1   8   5   3    4
# 9    10         Everton  2  1  1  0   3   1   2    4
# 10   11      Sunderland  3  1  1  1   3   3   0    4
# 11   12      Man United  2  1  0  1   5   4   1    3
# 12   13  Crystal Palace  3  1  0  2   4   8  -4    3
# 13   13    Ipswich Town  3  1  0  2   4   8  -4    3
# 14   15     Bournemouth  3  0  2  1   4   5  -1    2
# 15   16      Nottingham  3  0  2  1   2   3  -1    2
# 16   17     Aston Villa  3  0  1  2   0   5  -5    1
# 17   17       Tottenham  3  0  1  2   0   5  -5    1
# 18   19          Fulham  3  0  0  3   4   7  -3    0
# 19   20   Coventry City  3  0  0  3   0   5  -5    0
