# %%
import numpy as np

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import pandas as pd
from premier_league import MatchStatistics

# Initialize with default database location or specify your own
stats = MatchStatistics()

# %%
stats.get_games_by_season("2024-2025", match_week=5)
# Out:
# [{'id': 'ce0fb1f5',
#   'home_team_id': '7c21e445',
#   'away_team_id': 'cff3d9bb',
#   'league_id': 1,
#   'home_goals': 0,
#   'away_goals': 3,
#   'home_team_points': 4,
#   'away_team_points': 10,
#   'date': '2024-09-21T12:30:00',
#   'match_week': 5,
#   'season': '2024-2025',
#   'home_team': {'id': '7c21e445', 'name': 'West Ham United'},
#   'away_team': {'id': 'cff3d9bb', 'name': 'Chelsea'},
#   'game_stats': [{'id': 4641,
#     'game_id': 'ce0fb1f5',
#     'team_id': '7c21e445',
#     'xG': 0.9,
#     'xA': 0.9,
#     'xAG': 0.5,
#     'shots_total_FW': 6,
#     'shots_total_MF': 6,
#     'shots_total_DF': 3,
#     'shots_on_target_FW': 4,
#     'shots_on_target_MF': 3,
#     'shots_on_target_DF': 0,
#     'shot_creating_chances_FW': 9,
#     'shot_creating_chances_MF': 10,
#     'shot_creating_chances_DF': 8,
#     'goal_creating_actions_FW': 0,
#     'goal_creating_actions_MF': 0,
#     'goal_creating_actions_DF': 0,
#     'passes_completed_FW': 55,
# ...

# %%
# Get games for a specific season (e.g., 2023-2024)
season_games = stats.get_games_by_season("2023-2024")

# Convert the list of dictionaries to a pandas DataFrame
df = pd.DataFrame(season_games)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       5 stats = MatchStatistics()
#       7 # Get games for a specific season (e.g., 2023-2024)
# ----> 8 season_games = stats.get_games_by_season("2023-2024")
#      10 # Convert the list of dictionaries to a pandas DataFrame
#      11 df = pd.DataFrame(season_games)
#
# TypeError: MatchStatistics.get_games_by_season() missing 1 required positional argument: 'match_week'
